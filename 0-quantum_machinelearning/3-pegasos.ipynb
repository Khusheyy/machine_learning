# %% [markdown]
# <!-- pegasos -> qsvc => quantum support vector classifier -->

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# appnope                 0.1.4
# asttokens               3.0.0
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.17
# decorator               5.2.1
# dill                    0.4.1
# executing               2.2.1
# fonttools               4.60.1
# ipykernel               6.30.1
# ipython                 9.6.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# joblib                  1.5.2
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# kiwisolver              1.4.9
# matplotlib              3.10.7
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# numpy                   2.3.3
# packaging               25.0
# pandas                  2.3.3
# parso                   0.8.5
# pexpect                 4.9.0
# pillow                  11.3.0
# pip                     25.2
# platformdirs            4.5.0
# prompt_toolkit          3.0.52
# psutil                  7.1.0
# ptyprocess              0.7.0
# pure_eval               0.2.3
# Pygments                2.19.2
# pylatexenc              2.11
# pyparsing               3.2.5
# python-dateutil         2.9.0.post0
# pytz                    2025.2
# pyzmq                   27.1.0
# qiskit                  2.5.1
# qiskit-machine-learning 0.9.0
# rustworkx               0.18.1
# scikit-learn            1.7.2
# scipy                   1.16.2
# seaborn                 0.13.2
# setuptools              83.0.0
# six                     1.17.0
# stack-data              0.6.3
# stevedore               5.9.0
# threadpoolctl           3.6.0
# tornado                 6.5.2
# traitlets               5.14.3
# typing_extensions       4.16.0
# tzdata                  2025.2
# wcwidth                 0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install qiskit
# Out:
# Requirement already satisfied: qiskit in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (2.5.1)
# Requirement already satisfied: numpy<3,>=2.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit) (2.3.3)
# Requirement already satisfied: scipy>=1.14 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit) (1.16.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit) (0.18.1)
# Requirement already satisfied: dill>=0.3 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit) (5.9.0)
# Requirement already satisfied: typing-extensions in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit) (4.16.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install qiskit[visualization]
# Out:
# zsh:1: no matches found: qiskit[visualization]
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install qiskit-machine-learning
# Out:
# Requirement already satisfied: qiskit-machine-learning in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (0.9.0)
# Requirement already satisfied: qiskit>=2.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit-machine-learning) (2.5.1)
# Requirement already satisfied: numpy>=2.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit-machine-learning) (2.3.3)
# Requirement already satisfied: scipy>=1.4 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit-machine-learning) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.2 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit-machine-learning) (1.7.2)
# Requirement already satisfied: setuptools>=40.1 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit-machine-learning) (83.0.0)
# Requirement already satisfied: dill>=0.3.4 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit-machine-learning) (0.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit>=2.0->qiskit-machine-learning) (0.18.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit>=2.0->qiskit-machine-learning) (5.9.0)
# Requirement already satisfied: typing-extensions in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from qiskit>=2.0->qiskit-machine-learning) (4.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in /Users/khushi-purohit/Documents/machine-learning/envml/lib/python3.13/site-packages (2.11)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.datasets import make_blobs

# example dataset
features, labels = make_blobs(n_samples=20, n_features=2, centers=2, random_state=3, shuffle=True)

# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

features = MinMaxScaler(feature_range=(0, np.pi)).fit_transform(features)

train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, train_size=15, shuffle=True
)

# %%
# number of qubits is equal to the number of features
num_qubits = 2

# number of steps performed during the training procedure
tau = 100

# regularization parameter
C = 1000

# %%
from qiskit.circuit.library import z_feature_map
from qiskit_machine_learning.utils import algorithm_globals

from qiskit_machine_learning.kernels import FidelityQuantumKernel

from qiskit_machine_learning.state_fidelities import ComputeUncompute
from qiskit.primitives import StatevectorSampler as Sampler

sampler = Sampler()
fidelity = ComputeUncompute(sampler=sampler)

algorithm_globals.random_seed = 12345

feature_map = z_feature_map(feature_dimension=num_qubits, reps=1)

qkernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=feature_map)

# %%
from qiskit_machine_learning.algorithms import PegasosQSVC

pegasos_qsvc = PegasosQSVC(quantum_kernel=qkernel, C=C, num_steps=tau)

# training
pegasos_qsvc.fit(train_features, train_labels)

# testing
pegasos_score = pegasos_qsvc.score(test_features, test_labels)
print(f"PegasosQSVC classification test score: {pegasos_score}")
# Out:
# PegasosQSVC classification test score: 1.0

# %%
grid_step = 0.2
margin = 0.2
grid_x, grid_y = np.meshgrid(
    np.arange(-margin, np.pi + margin, grid_step), np.arange(-margin, np.pi + margin, grid_step)
)

# %%
meshgrid_features = np.column_stack((grid_x.ravel(), grid_y.ravel()))
meshgrid_colors = pegasos_qsvc.predict(meshgrid_features)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
meshgrid_colors = meshgrid_colors.reshape(grid_x.shape)
plt.pcolormesh(grid_x, grid_y, meshgrid_colors, cmap="RdBu", shading="auto")

plt.scatter(
    train_features[:, 0][train_labels == 0],
    train_features[:, 1][train_labels == 0],
    marker="s",
    facecolors="w",
    edgecolors="r",
    label="A train",
)
plt.scatter(
    train_features[:, 0][train_labels == 1],
    train_features[:, 1][train_labels == 1],
    marker="o",
    facecolors="w",
    edgecolors="b",
    label="B train",
)

plt.scatter(
    test_features[:, 0][test_labels == 0],
    test_features[:, 1][test_labels == 0],
    marker="s",
    facecolors="r",
    edgecolors="r",
    label="A test",
)
plt.scatter(
    test_features[:, 0][test_labels == 1],
    test_features[:, 1][test_labels == 1],
    marker="o",
    facecolors="b",
    edgecolors="b",
    label="B test",
)

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.title("Pegasos Classification")
plt.show()
