# %% [markdown]
# univariate analysis - only one col independently

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('titanic.jpg')
plt.imshow(img)
plt.axis("off")  # hide axes
plt.show()

# %%
# questions like - how your data looks? what are the type of cols - df.info()

# %%
# !pip install pillow
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../4-data/Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# *catagorical data*
# like pclass, embarked,sex, survived, pclass
# - use countplots
# - use pie chart

# %%
sns.countplot(data=df, x='Survived')
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Pclass')
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Embarked')
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# pie chart
df['Survived'].value_counts().plot(kind ='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind ='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **numerical data**
# - use histograms - create bins for ranges
# -

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins = 50)
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 27., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %%
sns.displot(df['Age'], kde=True)
# pdf - probability density function
# kde - kernel density estimation

# %%
# skewness - how much the data is shifted to one side
# normal distribution - salary of ppl, height of ppl

# %%
# box plot
sns.boxplot(df['Fare'], orient='h', color='lightblue')
# Out:
# <Axes: xlabel='Fare'>

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)
